# %%
from pptx import Presentation

from utils.constants import MESES
from utils.funcoes_tratamento_pptx import replace_text, replace_text_table_header

# %%
ano=2021
mes=7

# %%
REPLACE_TABLE_HEAD = {
    'MÊS ANO': f'{MESES[mes].upper()} {ano}',
    'JAN A MÊS': f'JAN A {MESES[mes].upper()}',
    'ACUMULADO ANO (JAN A MÊS)': f'ACUMULADO {ano} (JAN A {MESES[mes].upper()})',
    'MÊS DE ANO (UPPER)': f'{MESES[mes].upper()} DE {ano}',
}

# %% [markdown]
# ### Ações nas próximas duas células
# - Definir ano e mês para trabalho;
# - Copiar o arquivo modelo na pasta referente ao mês correspondente, devidamente renomeado

# %%
replace_text(
    f'files/modelo_apresentacao/Modelo (Novo) GDO 23º BPM.pptx',
    f'files/{ano}/{mes}/GDO 23º BPM - {MESES[mes].upper()}-{ano}.pptx',
    {'Mês de Ano': f'{MESES[mes].capitalize()} de {ano}'}
)

# %%
replace_text_table_header(
    f'files/{ano}/{mes}/GDO 23º BPM - {MESES[mes].upper()}-{ano}.pptx',
    f'files/{ano}/{mes}/GDO 23º BPM - {MESES[mes].upper()}-{ano}.pptx',
    REPLACE_TABLE_HEAD
)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_parent', '_tbl', 'notify_height_changed', 'part']

# %%
print(ids_tables)
print(ids_tables_novo)
print(ids_tables_aaa)
# Out:
# [47, 48, 53, 55, 60, 61, 66, 67, 72, 74, 78, 79, 84, 85, 91, 92, 98, 99, 104, 105, 111, 114]
# [89, 90, 94, 96, 101, 102, 106, 107, 110, 112, 114, 115, 118, 119, 123, 124, 128, 129, 132, 133, 137, 140]
# [87, 92, 97, 98, 103]

# %% [markdown]
# ## Exibe os seguintes valores de cada tabela da apresentação:
# - Index do slide;
# - Index do slide;
# - Id do shape;
# - Valor da célula 00
# - Se as células 00 is_merge_origin e spanned
# - Se as células 01 e 10 são spanned

# %%
prs = Presentation('files/modelo_apresentacao/Modelo (Novo) GDO 23º BPM.pptx')

slidenr = 0
shapenr = 0

for slide in prs.slides:
    for shape in slide.shapes:
        if not shape.has_table:
            continue
        r=0
        c=0
        print(f'Slide: {slidenr}')
        print(f'shape: {shapenr}')
        print(f'table_id: {shape.shape_id}')
        print(f'Cell 0_0: {shape.table.cell(0,0).text}')
        print(f'Cell 00 is_merge_origin: {shape.table.cell(0,0).is_merge_origin}')
        print(f'Cell 00 is_spanned: {shape.table.cell(0,0).is_spanned}')
        print(f'Cell 01 is_spanned: {shape.table.cell(0,1).is_spanned}')
        print(f'Cell 10 is_spanned: {shape.table.cell(1,0).is_spanned}')

        print('*'*40)
        shapenr+=1
        if shape.table.cell(0,0).text == 'aaa':
            ids_tables_aaa.append(shape.shape_id)
        else:
            ids_tables_novo.append(shape.shape_id)            
    slidenr+=1
    shapenr=0
# Out:
# Slide: 3
# shape: 0
# table_id: 47
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 3
# shape: 1
# table_id: 48
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 4
# shape: 0
# table_id: 51
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 4
# shape: 1
# table_id: 53
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 5
# shape: 0
# table_id: 56
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 5
# shape: 1
# table_id: 57
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 7
# shape: 0
# table_id: 60
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 7
# shape: 1
# table_id: 61
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 8
# shape: 0
# table_id: 64
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 8
# shape: 1
# table_id: 66
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 9
# shape: 0
# table_id: 68
# Cell 0_0: MÊS ANO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: True
# Cell 10 is_spanned: False
# ****************************************
# Slide: 9
# shape: 1
# table_id: 69
# Cell 0_0: ACUMULADO ANO (JAN A MÊS)
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: True
# Cell 10 is_spanned: False
# ****************************************
# Slide: 10
# shape: 0
# table_id: 72
# Cell 0_0: MÊS ANO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: True
# Cell 10 is_spanned: False
# ****************************************
# Slide: 10
# shape: 1
# table_id: 73
# Cell 0_0: ACUMULADO ANO (JAN A MÊS)
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: True
# Cell 10 is_spanned: False
# ****************************************
# Slide: 12
# shape: 0
# table_id: 77
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 12
# shape: 1
# table_id: 78
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 14
# shape: 0
# table_id: 82
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 14
# shape: 1
# table_id: 83
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 16
# shape: 0
# table_id: 86
# Cell 0_0: FRAÇÃO
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: True
# ****************************************
# Slide: 16
# shape: 1
# table_id: 87
# Cell 0_0: NÍVEL DE DESEMPENHO
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************
# Slide: 18
# shape: 0
# table_id: 91
# Cell 0_0: UNIDADE/FRAÇÃO:
# Cell 00 is_merge_origin: True
# Cell 00 is_spanned: False
# Cell 01 is_spanned: True
# Cell 10 is_spanned: False
# ****************************************
# Slide: 19
# shape: 0
# table_id: 94
# Cell 0_0: INDICADORES
# Cell 00 is_merge_origin: False
# Cell 00 is_spanned: False
# Cell 01 is_spanned: False
# Cell 10 is_spanned: False
# ****************************************

# %%
ids_tables
# Out:
# {'TCV': 48}

# %%
prs = Presentation('files/modelo_apresentacao/Modelo (Novo) GDO 23º BPM.pptx')

IDENTIFICADORES_INDICADORES: [
    'TCV', 'THC', 'TQF', 'IAF', 'TRI', 'ARMAS', 'IEfic', 
]

ids_tables = {}

slidenr = 0
shapenr = 0


for slide in prs.slides:
    for shape in slide.shapes:
        if not shape.has_table:
            continue
        for r in range(200):
            try:
                shape.table.cell(r, 0)
            except IndexError:                
                continue
            for c in range(200):
                try:
                    shape.table.cell(r,c)
                    
                    if 'TCV' in shape.table.cell(r, c).text:
                        if 'TCV' not in ids_tables:
                            ids_tables['TCV'] = shape.shape_id                            
                            continue
                    if 'THC' in shape.table.cell(r, c).text:
                        if 'THC' not in ids_tables:
                            ids_tables['THC'] = shape.shape_id                            
                            continue
                    if 'TQF' in shape.table.cell(r, c).text:
                        if 'TQF' not in ids_tables:
                            ids_tables['TQF'] = shape.shape_id                            
                            continue
                    if 'ARMAS' in shape.table.cell(r, c).text:
                        if 'ARMAS' not in ids_tables:
                            ids_tables['IAF'] = shape.shape_id                            
                            continue
                    if 'TRI' in shape.table.cell(r, c).text:
                        if 'TRI' not in ids_tables:
                            ids_tables['TRI'] = shape.shape_id                            
                            continue
                    if 'EFETIVIDADE' in shape.table.cell(r, c).text:
                        if 'EFETIVIDADE' not in ids_tables:
                            ids_tables['RQV'] = shape.shape_id                            
                            continue
                    if 'DENÚNCIAS' in shape.table.cell(r, c).text:
                        if 'DENÚNCIAS' not in ids_tables:
                            ids_tables['DDU'] = shape.shape_id                            
                            continue
                    if 'TOLS' in shape.table.cell(r, c).text:
                        if 'TOLS' not in ids_tables:
                            ids_tables['OLS'] = shape.shape_id                            
                            continue
                    if 'QTD OP' in shape.table.cell(r, c).text:
                        if 'QTD OP' not in ids_tables:
                            ids_tables['POG'] = shape.shape_id                            
                            continue
                    
                        print(f'Slide: {slidenr}')
                        print(f'Shape: {shapenr}')
                        print(f'Cell address: ({r},{c})')
                        
                        print(f'Conteúdo: {shape.table.cell(r,c).text}')
                        print('-'*40)
                        
                        continue
                except IndexError:
                    continue
                c+=1
            r+=1
        shapenr+=1
    slidenr+=1
    shapenr=0
ids_tables
# Out:
# {'TCV': 48,
#  'THC': 51,
#  'TQF': 56,
#  'IAF': 94,
#  'TRI': 66,
#  'RQV': 94,
#  'DDU': 73,
#  'OLS': 83,
#  'POG': 86}

# %%
prs = Presentation(f'files/modelo_apresentacao/Modelo (Novo) GDO 23º BPM.pptx')

shapes.get(ids_tables['TCV'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4089/3334471240.py in <module>
#       1 prs = Presentation(f'files/modelo_apresentacao/Modelo (Novo) GDO 23º BPM.pptx')
#       2
# ----> 3 prs.shapes.get(ids_tables['TCV'])
#       4 print(slide)
#
# AttributeError: 'Presentation' object has no attribute 'shapes'

# %%
ids_tables['TCV']
# Out:
# 48

# %% [markdown]
# ### Ações na próxima célula
# - Substituir o texto do primeiro slide

# %%
prs = Presentation('GDO - TESTE.pptx')

slide_0 = prs.slides[0]
shape_mes_ano = slide_0.shapes[1]
text_frame = shape_mes_ano.text_frame
paragraph = text_frame.paragraphs[0]
paragraph.runs[0].text = f'{MESES[mes].capitalize()} de {ano}'
prs.save('result.pptx')

# %% [markdown]
# ### Ações na próxima célula
# - Criar dicionário com itens para substituição dos textos nas tabelas da apresentação

# %%
replace_table_head = {
    'MÊS ANO': f'{MESES[mes].upper()} {ano}',
    'JAN A MÊS': f'JAN A {MESES[mes].upper()}',
    'ACUMULADO ANO (JAN A MÊS)': f'ACUMULADO {ano} (JAN A {MESES[mes].upper()})',
    'MÊS DE ANO (UPPER)': f'{MESES[mes].upper()} DE {ano}',
}

# %%
prs = Presentation('GDO - TESTE.pptx')

def replace_text_table(path_name_source_file, replace_dict, mes, ano, path_name_result_file)
    prs = Presentation(path_name_file)
    for slide in prs.slides:
        for shape in slide.shapes:
                for match, replacement in replace_dict.items():
                    if shape.has_table:
                        for cell in shape.table.iter_cells():                    
                            if match in cell.text:                                                        
                                for paragraph in cell.text_frame.paragraphs:
                                   for run in paragraph.runs:
                                       p = paragraph._p  # the lxml element containing the `<a:p>` paragraph element
        #                            remove all but the first run
                                       for idx, run in enumerate(paragraph.runs):
                                           if idx == 0:
                                               continue
                                           p.remove(run._r)
                                       cur_text = run.text
                                       new_text = cur_text.replace(str(match), str(replacement))
                                       run.text = new_text
    prs.save(f'files/{ano}/{mes}/result.pptx')

# %% [markdown]
# ### Ações na próxima célula:
# - Substituir os cabecalhos em todas as tabelas

# %%
sliden = 0
shapen = 0
tablen = 1
celln = 0
for slide in prs.slides:    
    for shape in slide.shapes:
        if shape.has_table:
            print(f'Slide: {sliden}')
            print(f'Shape: {shapen}')
            print(f'Table: {tablen}')            
            print('#'*30)            
            table = shape.table            
            for cell in table.iter_cells():                
                print('-'*3)
                print(f'CELL: {celln}')                                                                                
                print(cell.text)
                celln+=1
                print('-'*3)            
            celln=1
            print('#'*30)
            tablen+=1
        shapen+=1
    shapen=0
    tablen=1
    sliden+=1
    print('*'*20)
prs.save('result1.pptx')
# Out:
# ********************
# ********************
# ********************
# Slide: 3
# Shape: 1
# Table: 1
# ##############################
# ---
# CELL:
# ---
# CELL: 11
# ☺
# ---
# ---
# CELL: 12
# ☺
# ---
# ---
# CELL: 13
# IAF - ÍNDICE DE APREENSÃO DE ARMAS DE FOGO
# ---
# ---
# CELL: 14
# ☺
# ---
# ---
# CELL: 15
# ☺
# ---
# ---
# CELL: 16
# TRI - TAXA DE REAÇÃO IMEDIATA
# ---
# ---
# CELL: 17
# ☺
# ---
# ---
# CELL: 18
# ☺
# ---
# ---
# CELL: 19
# RQV – REPRESSÃO QUALIFICADA DA VIOLÊNCIA
# ---
# ---
# CELL: 20
# ☺
# ---
# ---
# CELL: 21
# ☺
# ---
# ---
# CELL: 22
# ÍNDICE DE EFETIVIDADE NO CUMPRIMENTO DE DDU
# ---
# ---
# CELL: 23
# ☺
# ---
# ---
# CELL: 24
# ☺
# ---
# ---
# CELL: 25
# IC – INTERAÇÃO COMUNITÁRIA
# ---
# ---
# CELL: 26
# ☺
# ---
# ---
# CELL: 27
# ☺
# ---
# ---
# CELL: 28
# IOLS - INDICADOR DE OPERAÇÃO LEI SECA
# ---
# ---
# CELL: 29
# ☺
# ---
# ---
# CELL: 30
# ☺
# ---
# ---
# CELL: 31
# OPERAÇÕES DO POG
# ---
# ---
# CELL: 32
# ☺
# ---
# ---
# CELL: 33
# ☺
# ---
# ##############################
# ********************
# ********************

# %%
for cell in prs.slides[3].shapes[2].table.iter_cells():
    if cell.text in replace_table_head:
        text_frame = cell.text_frame
        
        whole_text = " ".join([r.text for r in paragraph.runs])
        whole_text = re.sub(replacement_string, new_text, whole_text)
            for idx, run in enumerate(paragraph.runs):
                if idx == 0:
                    continue
                p = paragraph._p
                p.remove(run._r)
            paragraph.runs[0].text = whole_text
        
        
        
        paragraph = text_frame.paragraphs[0]
        paragraph.runs.text = replace_table_head[cell.text]
#         cell.text = replace_table_head[cell.text]
prs.save('result1.pptx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3663/568349988.py in <module>
#       3         text_frame = cell.text_frame
#       4         paragraph = text_frame.paragraphs[0]
# ----> 5         paragraph.runs.text = replace_table_head[cell.text]
#       6 #         cell.text = replace_table_head[cell.text]
#       7 prs.save('result1.pptx')
#
# AttributeError: 'tuple' object has no attribute 'text'

# %%
def replace_text_in_shapes(replace_table, shape):
    """Takes dict of {match: replacement, ... } and replaces all matches.
    Currently not implemented for charts or graphics.
    """
    text_frame = shape.text_frame
    paragraph.runs[0]
    
    
    for shape in shapes:
        for match, replacement in replacements.items():
            if shape.has_text_frame:
                if (shape.text.find(match)) != -1:
                    text_frame = shape.text_frame
                    for paragraph in text_frame.paragraphs:
                        whole_text = "".join(run.text for run in paragraph.runs)
                        whole_text = whole_text.replace(str(match), str(replacement))
                        for idx, run in enumerate(paragraph.runs):
                            if idx != 0:
                                p = paragraph._p
                                p.remove(run._r)
                        if(not(not paragraph.runs)):
                            paragraph.runs[0].text = whole_text

if __name__ == '__main__':

    prs = Presentation('GDO - TESTE.pptx')
    # To get shapes in your slides
    slides = [slide for slide in prs.slides]
    shapes = []
    for slide in slides:
        for shape in slide.shapes:
            shapes.append(shape)

    replace_text_in_shapes(replaces, shapes)
    prs.save('output.pptx')
