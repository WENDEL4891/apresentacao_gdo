# %%
import pandas as pd

# %%
df_ols_infracoes = pd.read_excel('files/dados/00.Indicador Operação Lei Seca - OLS_GDO_2021 (2).xls', sheet_name='INFRACAO_BD')
df_ols_crimes = pd.read_excel('files/dados/00.Indicador Operação Lei Seca - OLS_GDO_2021 (2).xls', sheet_name='CRIME_BD')
# Out:
# WARNING *** file size (125065) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (125065) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df_ols_crimes = df_ols_crimes[
    ['Número REDS', 'Ano Fato', 'Mês Numérico Fato', 'Data Fato',
       'Município', 'Bairro', 'Logradouro Ocorrência', 'Bairro Não Cadastrado',
       'Logradouro Ocorrência Não Cadastrado', 'Complemento Endereço',
       'Ponto de Referência', 'Qtde Ocorrências']
]

df_ols_infracoes = df_ols_infracoes[
    ['Número REDS', 'Ano Fato', 'Mês Numérico Fato', 'Data Fato',
       'Município', 'Bairro', 'Logradouro Ocorrência', 'Bairro Não Cadastrado',
       'Logradouro Ocorrência Não Cadastrado', 'Complemento Endereço',
       'Ponto de Referência', 'Qtde Ocorrências']
]

# %%
df_ols = pd.concat([df_ols_infracoes, df_ols_crimes])

# %%
df_ols.drop_duplicates('Número REDS', keep='first', inplace=True)

# %%
df_ols.shape
# Out:
# (205, 12)
