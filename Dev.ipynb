# %%
import pandas as pd
import emoji

from utils.funcoes import definir_campos
from utils.funcoes import get_df_classif
from utils.funcoes import classifica_setor
from utils.funcoes import classifica_cia

# %% [markdown]
# ## Escolha o ano e o mês ⬇

# %%
ano=2021
mes=7

# %%
df_classificadores = get_df_classif()

# %%
df_ols_infracoes = pd.read_excel(f'files/dados/{ano}/{mes}/00.Indicador Operação Lei Seca - OLS_GDO_2021.xls', sheet_name='INFRACAO_BD')
df_ols_crimes = pd.read_excel(f'files/dados/{ano}/{mes}/00.Indicador Operação Lei Seca - OLS_GDO_2021.xls', sheet_name='CRIME_BD')
df_ols_crimes = definir_campos(df_ols_crimes)
df_ols_infracoes = definir_campos(df_ols_infracoes)
df_ols = pd.concat([df_ols_infracoes, df_ols_crimes]).set_index('NREDS').sort_index().fillna('')
df_ols['SETOR'] = df_ols.apply(lambda row: classifica_setor(row, df_classificadores), axis=1)
classifica_cia(df_ols)
df_ols
# Out:
# WARNING *** file size (125074) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (125074) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#                     ANO_FATO  MES_FATO  DATA_FATO    MUNICIPIO       BAIRRO  \
# NREDS
# 2021-000003781-001      2021         1 2021-01-01  DIVINOPOLIS   INTERLAGOS
# 2021-000006484-001      2021         1 2021-01-01  DIVINOPOLIS       CENTRO
# 2021-000018780-001      2021         1 2021-01-01  DIVINOPOLIS  PORTO VELHO
# 2021-000299830-001      2021         1 2021-01-03  DIVINOPOLIS  SANTA LUZIA
# 2021-000299830-001      2021         1 2021-01-03  DIVINOPOLIS  SANTA LUZIA
# ...                      ...       ...        ...          ...          ...
# 2021-040445527-001      2021         8 2021-08-22  DIVINOPOLIS       CENTRO
# ...
